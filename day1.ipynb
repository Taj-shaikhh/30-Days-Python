# %% [markdown]
# # Variables, Data Types & Input/Output

# %%
name = "Taj"
age = 22
print(name)
print(age)
# Out:
# Taj
# 22

# %%
price = 99.99
print(type(price))
# Out:
# <class 'float'>

# %%
num1 = int(input("Enter first number"))
num2 = int(input("Enter Second number"))

# %%
print("sum =" , num1 + num2 )
# Out:
# sum = 47

# %%
model_name = "Random Forest"
accuracy = 97.5
print("Model_name :", model_name)
print("Accuracy :", accuracy)
# Out:
# Model_name : Random Forest
# Accuracy : 97.5

# %% [markdown]
# # Mini Exercise

# %%
# Exercise 1 :
name = "Tajuddin Shaikh"
age = 22
goal = "To become an AI Engineer"
print(name)
print(age)
print(goal)
# Out:
# Tajuddin Shaikh
# 22
# To become an AI Engineer

# %%
user1 = int(input("Enter first number"))
user2 = int(input("Enter second number"))
print("add :",user1 + user2)
print("subtract :", user1 - user2)
print("multiply :", user1 * user2)
# Out:
# add : 50
# subtract : -10
# multiply : 600

# %%
dataset_name = "Home_Loan_Dataset"
model_accuracy = 80.50
is_trained = True
print(type(dataset_name))
print(type(model_accuracy))
print(type(is_trained))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
user_name = input("Enter your name")
print(user_name)
# Out:
# Salman Khan

# %%
age = "50"
age1 = int(age)
print(age1)
# Out:
# 50

# %%
stu_name = input("Enter student name")

phy_marks = int(input("Enter physics marks"))
chemst_marks = int(input("Enter chemistry marks"))
math_marks = int(input("Enter math marks"))

total_marks = phy_marks + chemst_marks + math_marks
avg_marks = total_marks/ 3

print(stu_name)
print(total_marks)
print(avg_marks)
# Out:
# Amman patel
# 255
# 85.0

# %%
celsius  = float(input("Enter Temperature in celsius :"))
fahrenheit = (celsius * 9/5) + 32
print("Fahrenheit :", fahrenheit)
# Out:
# Fahrenheit : 86.0

# %%
# problem no. 6
Dataset = input("Enter the dataset name :")
rows = input("Enter number of rows :")
columns = input("Enter number of columns :")
accuracy = input("Enter accuracy ")
print("Dataset :", Dataset)
print("rows:",rows)
print("columns :", columns)
print("Accuracy : ", accuracy)
# Out:
# Dataset : Iris_dataset
# rows: 40k
# columns : 40
# Accuracy :  60%

# %%
a = int(input("enter first  number :"))
b = int(input("enter second number :"))
print("Before Swap :")
print("a = ", a)
print("b = ", b)
print("After Swap :")
print("a = ", b)
print("b = ", a)
# Out:
# Before Swap :
# a =  30
# b =  60
# After Swap :
# a =  60
# b =  30

# %%
width = float(input("Enter width "))
height = float(input("Enter height"))
channels = int(input("Enter chanels "))
print("Image Resoultion : ",width, "x", height )
print("Channels : ", channels)
# Out:
# Image Resoultion :  1920.0 x 1080.0
# Channels :  3

# %%
# Problem no. 9
principal_amt = float(input("Enter principal amount :"))
rate_int = float(input("Enter rate of interest :"))
time = float(input("Enter time :"))

simple_interest = (principal_amt * rate_int * time)/ 100

print("Simple Interest :", simple_interest)
# Out:
# Simple Interest : 72000.0
