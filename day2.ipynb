# %%
# Problem 1 : Create a list containing 5 favorite movies. 
# Print: entire list, first movie, last movie.

movies = ["wxyz", "abcd", "efgi", "mnop", "pqrs"]
print(movies)
print(movies[0])
print(movies[4])

new_movies = input("enter new movie name :")
movies.append(new_movies)
print(movies)
# Out:
# ['wxyz', 'abcd', 'efgi', 'mnop', 'pqrs']
# wxyz
# pqrs
# ['wxyz', 'abcd', 'efgi', 'mnop', 'pqrs', 'aabbccdd']

# %%
student_marks = [85, 99, 80, 75, 65]
print(student_marks[0])
print(student_marks[2])
print(student_marks[-1])
# Out:
# 85
# 80
# 65

# %%
# problem 3
language = ["python", "java"]
language.append("c++")
print(language)
# Out:
# ['python', 'java', 'c++']

# %%
# Problem  4 Count Subjects
subjects = ["Math", "Englis", "Biology", "Chemistry"]
print(len(subjects))
# Out:
# 4

# %%
# problem 5 
resolution = (1920, 1080)
print("Width :",resolution[0])
print("Height :",resolution[1])
# Out:
# Width : 1920
# Height : 1080

# %%
# Problem 6 
labels = {"Dog", "Cat", "Dog", "Bird", "Cat"}
print(labels)
# Out:
# {'Bird', 'Dog', 'Cat'}

# %%
# Problem 7
student = {
    "name" : "Taj Shaikh",
    "age" : 22,
    "course" : "AI"
}
print(student)
# Out:
# {'name': 'Taj Shaikh', 'age': 22, 'course': 'AI'}

# %%
# Problem 8
Dataset = {
    "name" : "Iris",
    "row" : 2000,
    "columns" : 20
}
print(Dataset)
# Out:
# {'name': 'Iris', 'row': 2000, 'columns': 20}

# %%
# Problem 9 
model = {
    "Model_name" : "Random Forest",
    "Accuracy" : 94.87,
    "Alogrithm" : "Classification"
}
print("Model:", model["Model_name"])
print("Accuracy:", model["Accuracy"])
print("Algorithm:", model["Alogrithm"])
# Out:
# Model: Random Forest
# Accuracy: 94.87
# Algorithm: Classification

# %%
# problem 10
Students = {
    "name" : "Irfan Pathan",
    "age" : 30,
    "marks" : 88,
    "city" : "Mumbai"
}
print(Students)
# Out:
# {'name': 'Irfan Pathan', 'age': 30, 'marks': 88, 'city': 'Mumbai'}

# %%
# Out:
# 'Irfan Pathan'
